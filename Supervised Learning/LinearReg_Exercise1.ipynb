# %% [markdown]
# ## 💻 Laptop Price Prediction - using Linear Regression model
#
# ### 🎯 Objectives:
# The goal of this exercise is to apply `Linear Regression` to predict laptop price based on available features.
# We will:
# - Import and read the dataset
# - Check for missing values
# - Train a linear regression model
# - Calculate the mean squared error (MSE)
# - Build a baseline model
# - Visualize the predictions to evaluate the model performance

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🗂️ Data Preparation

# %%
#import kagglehub

# Download latest version
#path = kagglehub.dataset_download("gyanprakashkushwaha/laptop-price-prediction-cleaned-dataset")

#print("Path to dataset files:", path)

# %%
# 1. Load dataset
df = pd.read_csv('laptop_data_cleaned.csv')
df.head()
# Out:
#   Company   TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0    0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os
# 0  Intel Core i5    0  128     Intel     Mac
# 1  Intel Core i5    0    0     Intel     Mac
# 2  Intel Core i5    0  256     Intel  Others
# 3  Intel Core i7    0  512       AMD     Mac
# 4  Intel Core i5    0  256     Intel     Mac

# %% [markdown]
# 🧹 Check for missing values and handle them using the dropna() function.

# %%
# Check for missing values

# Drop rows with missing values (if any)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int64
#  3   Weight       1273 non-null   float64
#  4   Price        1273 non-null   float64
#  5   TouchScreen  1273 non-null   int64
#  6   Ips          1273 non-null   int64
#  7   Ppi          1273 non-null   float64
#  8   Cpu_brand    1273 non-null   object
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu_brand    1273 non-null   object
#  12  Os           1273 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 129.4+ KB

# %%
# Run this cell to encode all categorical columns using one-hot encoding
cat_cols = df.select_dtypes(include='object').columns
df = pd.get_dummies(df, columns=cat_cols, drop_first=True) 

df.head()
# Out:
#    Ram  Weight      Price  TouchScreen  Ips         Ppi  HDD  SSD  \
# 0    8    1.37  11.175755            0    1  226.983005    0  128
# 1    8    1.34  10.776777            0    0  127.677940    0    0
# 2    8    1.86  10.329931            0    0  141.211998    0  256
# 3   16    1.83  11.814476            0    1  220.534624    0  512
# 4    8    1.37  11.473101            0    1  226.983005    0  256
#
#    Company_Apple  Company_Asus  ...  TypeName_Ultrabook  TypeName_Workstation  \
# 0           True         False  ...                True                 False
# 1           True         False  ...                True                 False
# 2          False         False  ...               False                 False
# 3           True         False  ...                True                 False
# 4           True         False  ...                True                 False
#
#    Cpu_brand_Intel Core i3  Cpu_brand_Intel Core i5  Cpu_brand_Intel Core i7  \
# ...

# %% [markdown]
# ### 🤖 Build Linear Regression Model - Predicting Laptop Price

# %% [markdown]
# In this exercise, `Price` is selected as the target variable we aim to predict.

# %%
# 1. Split the features and the target (Target: 'Price')

# 2. Split the data into training and test sets

# 3. Create a Linear Regression model

# 4. Fit the model to the training data

# 5. Predict the scores using the test data

# 6. Calculate and print the Mean Squared Error (MSE)

# %% [markdown]
# ### ⚙️ Build Baseline Model

# %%
# 1. Create a baseline predection model

# 2. Calculate and print the baseline MES

# %% [markdown]
# ### 📉 Visualization

# %%
# 1. Create the figure and set its size

# 2. Plot a scatter plot of actual vs predicted values

# 3. Draw a dashed line from min to max as a reference

# 4. Label the x-axis and y-axis

# 5. Add a title to the plot

# 6. Add a grid

# 7. Show the plot
